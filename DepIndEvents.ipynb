# %% [markdown]
# <a href="https://colab.research.google.com/github/pooja-github16/PythonPractice/blob/main/DepIndEvents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Independent Events

# %%
import random

def roll_dice():
    return random.randint(1, 6)

def flip_coin():
    return random.choice(['heads', 'tails'])

print("Dice Roll:", roll_dice())
print("Coin Flip:", flip_coin())
# Out:
# Dice Roll: 5
# Coin Flip: heads

# %% [markdown]
# ### Dependent Events
# Here Assume the full deck i.e 52 cards so let's say we drew an Ace so the probability to draw another ACE drops fros 4/52 to 3/52

# %%
deck = ['Ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King']

def draw_card():
    card = random.choice(deck)
    deck.remove(card)
    return card

print("Card Drawn:", draw_card())
print("Cards remaining in deck:", deck,"Cards remaining: ",len(deck))
# Out:
# Card Drawn: 9
# Cards remaining in deck: ['Ace', '2', '3', '4', '5', '6', '7', '8', '10', 'Jack', 'Queen', 'King'] Cards remaining:  12
